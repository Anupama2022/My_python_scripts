# %% [markdown]
# # Pandas challenges

# %% [markdown]
# Read the `veahicles.csv` dataframe and store it in a variable called `cars`:

# %%
import pandas as pd
cars=pd.read_csv('vehicles.csv')
print(cars)
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# Explore the dataset:
#
# - How many rows and columns are there?
#
# - What are the data types of the columns?
#
# - Are there missing values?
#
# - What are the ranges / distributions of the numerical columns?
#
# - What are the value counts for the categorical columns?

# %%
cars.info()
#15 columns & 35951 rows
#datatypes = float64(4), int64(4), object(6)
#there are missing values
cars.describe()
cars.Transmission.value_counts()
cars.Drivetrain.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
#  14  Fuel Cost/Year           35952 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 4.1+ MB
# Front-Wheel Drive             13044
# Rear-Wheel Drive              12726
# 4-Wheel or All-Wheel Drive     6503
# All-Wheel Drive                2039
# 4-Wheel Drive                  1058
# 2-Wheel Drive                   423
# Part-time 4-Wheel Drive         158
# 2-Wheel Drive, Front              1
# Name: Drivetrain, dtype: int64

# %% [markdown]
# Drop the column "Combined MPG"

# %%
cars['Combined MPG']
# Out:
# 0        17
# 1        13
# 2        16
# 3        13
# 4        16
#          ..
# 35947    36
# 35948    36
# 35949    36
# 35950    36
# 35951    35
# Name: Combined MPG, Length: 35952, dtype: int64

# %% [markdown]
# Change column names so that there are no names with spaces or weird special characters:

# %%
cars_new=cars.copy()
cars.rename(columns={"Vehicle Class": "Vehicleclass", "Engine Displacement" :"Enginedisplacement", "Highway MPG" : "HighwayMPG" , "CO2 Emission Grams/Mile" : "CO2Emission"}, inplace = True)
cars
# Out:
#                    Make                Model  Year  Enginedisplacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                 2.5
# 1            AM General     FJ8c Post Office  1984                 4.2
# 2            AM General  Post Office DJ5 2WD  1985                 2.5
# 3            AM General  Post Office DJ8 2WD  1985                 4.2
# 4      ASC Incorporated                  GNX  1987                 3.8
# ...                 ...                  ...   ...                 ...
# 35947             smart         fortwo coupe  2013                 1.0
# 35948             smart         fortwo coupe  2014                 1.0
# 35949             smart         fortwo coupe  2015                 1.0
# 35950             smart         fortwo coupe  2016                 0.9
# 35951             smart         fortwo coupe  2016                 0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                       Vehicleclass Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        HighwayMPG  Combined MPG  CO2Emission  Fuel Cost/Year
# 0              17            17   522.764706            1950
# 1              13            13   683.615385            2550
# 2              17            16   555.437500            2100
# 3              13            13   683.615385            2550
# 4              21            16   555.437500            2550
# ...           ...           ...          ...             ...
# 35947          38            36   244.000000            1100
# 35948          38            36   243.000000            1100
# 35949          38            36   244.000000            1100
# 35950          39            36   246.000000            1100
# 35951          39            35   255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# print(cars)
# What brand has the most cars?

# %%
cars.Make
cars.Make.value_counts()
print(cars)
#Chevrolet
# Out:
#                    Make                Model  Year  Enginedisplacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                 2.5
# 1            AM General     FJ8c Post Office  1984                 4.2
# 2            AM General  Post Office DJ5 2WD  1985                 2.5
# 3            AM General  Post Office DJ8 2WD  1985                 4.2
# 4      ASC Incorporated                  GNX  1987                 3.8
# ...                 ...                  ...   ...                 ...
# 35947             smart         fortwo coupe  2013                 1.0
# 35948             smart         fortwo coupe  2014                 1.0
# 35949             smart         fortwo coupe  2015                 1.0
# 35950             smart         fortwo coupe  2016                 0.9
# 35951             smart         fortwo coupe  2016                 0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                       Vehicleclass Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        HighwayMPG  Combined MPG  CO2Emission  Fuel Cost/Year
# 0              17            17   522.764706            1950
# 1              13            13   683.615385            2550
# 2              17            16   555.437500            2100
# 3              13            13   683.615385            2550
# 4              21            16   555.437500            2550
# ...           ...           ...          ...             ...
# 35947          38            36   244.000000            1100
# 35948          38            36   243.000000            1100
# 35949          38            36   244.000000            1100
# 35950          39            36   246.000000            1100
# 35951          39            35   255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# What brand has the worse CO2 Emissions on average?

# %%
co2 = cars.groupby('Make')['CO2EmissionGramsPerMile'].mean()
cars["CO2 Emission Grams/Mile"]
max(cars["CO2 Emission Grams/Mile"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13920/1871121398.py in <module>
# ----> 1 co2 = cars.groupby('Make')['CO2EmissionGramsPerMile'].mean()
#       2 cars["CO2 Emission Grams/Mile"]
#       3 max(cars["CO2 Emission Grams/Mile"])
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     230         else:
#     231             if key not in self.obj:
# --> 232                 raise KeyError(f"Column not found: {key}")
#     233             subset = self.obj[key]
#     234             ndim = subset.ndim
#
# KeyError: 'Column not found: CO2EmissionGramsPerMile'

# %% [markdown]
# Which brands are more environment friendly?

# %%
min(cars["CO2 Emission Grams/Mile"])
# Out:
# 37.0

# %% [markdown]
# Create 4 groups (bins) of cars, by Year. We want to explore how cars have evolved decade by decade.

# %%
cars.Year.value_counts()
#car_year = cars.groupby("Year")
car_year = cars.sort_values("Year")
#print(car_year)
cars_new_index = car_year.set_index("Year")
car_eighty1 =  cars_new_index.loc[1980:1989,]
cars_eighty= car_eighty1.describe().loc["mean":"mean",]
cars_ninety1 = cars_new_index.loc[1990:1999,]
cars_ninety = cars_ninety1.describe().loc["mean":"mean",]

cars_twenty1 = cars_new_index.loc[2000:2009, ]
cars_twenty = cars_twenty1.describe().loc["mean":"mean",]
cars_twenty_ten1 = cars_new_index.loc[2010:2020, ]
cars_twenty_ten =cars_twenty_ten1.describe().loc["mean":"mean",]


cars_1 = pd.concat([cars_eighty,cars_ninety])
cars_2 = pd.concat([cars_1, cars_twenty])
cars_decade1 = pd.concat([cars_2,cars_twenty_ten])
Decade = ["1980", "1990", "2000", "2010"]
cars_decade1["Decade"] = Decade
cars_decade = cars_decade1.set_index("Decade")

print(cars_decade)
# Out:
#         Engine Displacement  Cylinders  Fuel Barrels/Year   City MPG  \
# Decade
# 1980               3.248702   5.489939          18.552822  17.327209
# 1990               3.275197   5.653241          18.293291  16.954091
# 2000               3.447019   5.993954          17.962477  16.834199
# 2010               3.345379   5.821849          15.778968  19.546763
#
#         Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# Decade
# 1980      22.389472     19.216973               499.853860     1898.067950
# 1990      22.839639     19.111583               493.678690     1929.633369
# 2000      23.205574     19.163722               486.007524     1972.489372
# 2010      26.866469     22.202550               425.395003     1757.237059

# %% [markdown]
# Did cars consume more gas in the eighties?

# %%
Yes

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission?

# %%
cars.sort_values("Fuel Barrels/Year", ascending=False)

#Nope
# Out:
#               Make              Model  Year  Engine Displacement  Cylinders  \
# 20898  Lamborghini           Countach  1990                  5.2       12.0
# 20896  Lamborghini           Countach  1988                  5.2       12.0
# 20895  Lamborghini           Countach  1987                  5.2       12.0
# 20894  Lamborghini           Countach  1986                  5.2       12.0
# 20897  Lamborghini           Countach  1989                  5.2       12.0
# ...            ...                ...   ...                  ...        ...
# 17296        Honda          Civic CNG  2009                  1.8        4.0
# 17396        Honda  Civic Natural Gas  2013                  1.8        4.0
# 17398        Honda  Civic Natural Gas  2015                  1.8        4.0
# 17397        Honda  Civic Natural Gas  2014                  1.8        4.0
# 17395        Honda  Civic Natural Gas  2012                  1.8        4.0
#
#           Transmission         Drivetrain    Vehicle Class Fuel Type  \
# 20898     Manual 5-spd   Rear-Wheel Drive      Two Seaters   Premium
# 20896     Manual 5-spd   Rear-Wheel Drive      Two Seaters   Premium
# 20895     Manual 5-spd   Rear-Wheel Drive      Two Seaters   Premium
# 20894     Manual 5-spd   Rear-Wheel Drive      Two Seaters   Premium
# 20897     Manual 5-spd   Rear-Wheel Drive      Two Seaters   Premium
# ...                ...                ...              ...       ...
# 17296  Automatic 5-spd  Front-Wheel Drive  Subcompact Cars       CNG
# 17396  Automatic 5-spd  Front-Wheel Drive     Compact Cars       CNG
# 17398  Automatic 5-spd  Front-Wheel Drive     Compact Cars       CNG
# 17397  Automatic 5-spd  Front-Wheel Drive     Compact Cars       CNG
# 17395  Automatic 5-spd  Front-Wheel Drive     Compact Cars       CNG
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 20898          47.087143         6           10             7
# 20896          47.087143         6           10             7
# 20895          47.087143         6           10             7
# 20894          47.087143         6           10             7
# 20897          47.087143         6           10             7
# ...                  ...       ...          ...           ...
# 17296           0.066429        24           36            28
# 17396           0.060000        27           38            31
# 17398           0.060000        27           38            31
# 17397           0.060000        27           38            31
# 17395           0.060000        27           38            31
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 20898              1269.571429            5800
# 20896              1269.571429            5800
# 20895              1269.571429            5800
# 20894              1269.571429            5800
# 20897              1269.571429            5800
# ...                        ...             ...
# 17296               253.197321            1100
# 17396               218.000000            1000
# 17398               218.000000            1000
# 17397               218.000000            1000
# 17395               228.694355            1000
#
# [35952 rows x 15 columns]

# %% [markdown]
# Group cars by fuel type and aggregate them by the following criteria:
#
# - The maximum number cylinders
# - The oldest year
# - The average Miles Per Gallon in the city

# %%
cars_grouped=cars.groupby(cars["Fuel Type"])

# %%
print(cars_grouped.Cylinders.value_counts())
#print(cars_grouped.Cylinders.max())
#cars.loc[cars.Transmission.str.contains('Man.')].comb_mpg.mean()
# Out:
# Fuel Type                    Cylinders
# CNG                          8.0             36
#                              4.0             21
#                              6.0              3
# Diesel                       8.0            421
#                              4.0            318
#                              6.0            151
#                              5.0             17
#                              10.0             4
# Gasoline or E85              8.0            709
#                              6.0            359
#                              4.0            127
# Gasoline or natural gas      8.0             13
#                              4.0              5
#                              6.0              2
# Gasoline or propane          8.0              8
# Midgrade                     8.0             69
#                              6.0              5
# Premium                      6.0           3950
#                              8.0           2589
#                              4.0           2382
#                              12.0           505
#                              5.0            298
#                              10.0           141
#                              3.0             26
#                              2.0             22
#                              16.0             8
# Premium Gas or Electricity   4.0             10
#                              2.0              3
#                              6.0              3
#                              8.0              1
# Premium and Electricity      4.0              9
#                              6.0              6
#                              3.0              3
#                              8.0              2
# Premium or E85               6.0             55
#                              4.0             28
#                              12.0            22
#                              8.0             16
# Regular                      4.0          10576
#                              6.0           8231
#                              8.0           4134
#                              5.0            408
#                              3.0            172
#                              12.0            35
#                              2.0             23
#                              10.0             8
# Regular Gas and Electricity  4.0             16
# Regular Gas or Electricity   4.0              2
# Name: Cylinders, dtype: int64

# %%
print(cars_grouped.Year.min())
#earliest year for each category of fuel type
# Out:
# Fuel Type
# CNG                            1993
# Diesel                         1984
# Gasoline or E85                2000
# Gasoline or natural gas        2000
# Gasoline or propane            2001
# Midgrade                       2011
# Premium                        1985
# Premium Gas or Electricity     2011
# Premium and Electricity        2014
# Premium or E85                 2004
# Regular                        1984
# Regular Gas and Electricity    2012
# Regular Gas or Electricity     2016
# Name: Year, dtype: int64

# %%
cars.Drivetrain.value_counts()
# Out:
# Front-Wheel Drive             13044
# Rear-Wheel Drive              12726
# 4-Wheel or All-Wheel Drive     6503
# All-Wheel Drive                2039
# 4-Wheel Drive                  1058
# 2-Wheel Drive                   423
# Part-time 4-Wheel Drive         158
# 2-Wheel Drive, Front              1
# Name: Drivetrain, dtype: int64

# %% [markdown]
# We want to use "Drivetrain" in a statistical model. Convert the column to numeric.

# %%
cars_grouped_numeric = pd.to_numeric("Drivetrain")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Drivetrain"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14356/329638404.py in <module>
# ----> 1 cars_grouped_numeric = pd.to_numeric("Drivetrain")
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Drivetrain" at position 0

# %% [markdown]
# Read the `car_brands.csv` data:

# %%
# code here

# %% [markdown]
# Join the cars dataframe with the car brands dataframe.

# %%
# code here

# %% [markdown]
# Which brands have the most revenue?

# %%
# code here
